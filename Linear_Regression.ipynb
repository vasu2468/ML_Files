# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("V:\\Datasets\\Life Expectancy Data.csv")

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria   HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0       0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0       0.1  612.696514    327582.0
# 2   62.0               8.13         64.0       0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0       0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0       0.1   63.537231   2978599.0
#
#    thin1-19  thin5-9  Income composition of resources  Schooling
# 0      17.2     17.3                            0.479       10.1
# 1      17.5     17.5                            0.476       10.0
# 2      17.7     17.7                            0.470        9.9
# 3      17.9     18.0                            0.463        9.8
# 4      18.2     18.2                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10  BMI                              2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
#  12  Polio                            2919 non-null   float64
#  13  Total expenditure                2712 non-null   float64
#  14  Diphtheria                       2919 non-null   float64
#  15  HIV/AIDS                         2938 non-null   float64
#  16  GDP                              2490 non-null   float64
#  17  Population                       2286 non-null   float64
#  18  thin1-19                         2904 non-null   float64
#  19  thin5-9                          2904 non-null   float64
#  20  Income composition of resources  2771 non-null   float64
#  21  Schooling                        2775 non-null   float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 505.1+ KB

# %%
sns.heatmap(pd.isnull(df))
# Out:
# <AxesSubplot:>

# %%
a=list(df.columns)
b=[]
for i in a:
    c=df[i].isnull().sum()
    b.append(c)
null_df=pd.DataFrame({'Feature name':a,'Nan Values':b})
null_df
# Out:
#                        Feature name  Nan Values
# 0                           Country           0
# 1                              Year           0
# 2                            Status           0
# 3                  Life expectancy           10
# 4                   Adult Mortality          10
# 5                     infant deaths           0
# 6                           Alcohol         194
# 7            percentage expenditure           0
# 8                       Hepatitis B         553
# 9                          Measles            0
# 10                             BMI           34
# 11               under-five deaths            0
# 12                            Polio          19
# 13                Total expenditure         226
# 14                      Diphtheria           19
# 15                         HIV/AIDS           0
# 16                              GDP         448
# 17                       Population         652
# 18                         thin1-19          34
# 19                          thin5-9          34
# 20  Income composition of resources         167
# 21                        Schooling         163

# %%
df['Life expectancy ']=df['Life expectancy '].fillna(value=df['Life expectancy '].mean())
df['Adult Mortality'] = df['Adult Mortality'].fillna(value = df['Adult Mortality'].mean())
df['Alcohol'] = df['Alcohol'].fillna(value = df['Alcohol'].mean())
df['Hepatitis B'] = df['Hepatitis B'].fillna(value = df['Hepatitis B'].mean())

# %%
df['BMI '] = df['BMI '].fillna(value = df['BMI '].mean())

# %%
df['Total expenditure'] = df['Total expenditure'].fillna(value = df['Total expenditure'].mean())
df['Diphtheria '] = df['Diphtheria '].fillna(value = df['Diphtheria '].mean())
df['GDP'] = df['GDP'].fillna(value = df['GDP'].mean())
df['Population'] = df['Population'].fillna(value = df['Population'].mean())

# %%
df['thin1-19'] = df['thin1-19'].fillna(value = df['thin1-19'].mean())

# %%
df['thin5-9'] = df['thin5-9'].fillna(value = df['thin5-9'].mean())
df['Income composition of resources'] = df['Income composition of resources'].fillna(value = df['Income composition of resources'].mean())
df['Schooling'] = df['Schooling'].fillna(value = df['Schooling'].mean())

# %%
corr_data=df.corr()
corr_data
# Out:
#                                      Year  Life expectancy   Adult Mortality  \
# Year                             1.000000          0.169623        -0.078861
# Life expectancy                  0.169623          1.000000        -0.696359
# Adult Mortality                 -0.078861         -0.696359         1.000000
# infant deaths                   -0.037415         -0.196535         0.078747
# Alcohol                         -0.048168          0.391598        -0.190408
# percentage expenditure           0.031400          0.381791        -0.242814
# Hepatitis B                      0.089398          0.203771        -0.138591
# Measles                         -0.082493         -0.157574         0.031174
# BMI                              0.108327          0.559255        -0.381449
# under-five deaths               -0.042937         -0.222503         0.094135
# Polio                            0.094158          0.464531        -0.274218
# Total expenditure                0.081860          0.207981        -0.110875
# Diphtheria                       0.133853          0.475418        -0.273014
# HIV/AIDS                        -0.139741         -0.556457         0.523727
# GDP                              0.093351          0.430493        -0.277053
# Population                       0.014951         -0.019638        -0.012501
# thin1-19                        -0.047592         -0.472162         0.299863
# thin5-9                         -0.050627         -0.466629         0.305366
# Income composition of resources  0.236333          0.692483        -0.440062
# Schooling                        0.203471          0.715066        -0.435108
#
#                                  infant deaths   Alcohol  \
# Year                                 -0.037415 -0.048168
# Life expectancy                      -0.196535  0.391598
# Adult Mortality                       0.078747 -0.190408
# infant deaths                         1.000000 -0.113812
# Alcohol                              -0.113812  1.000000
# percentage expenditure               -0.085612  0.339634
# Hepatitis B                          -0.178783  0.075447
# Measles                               0.501128 -0.051055
# BMI                                  -0.227220  0.318070
# under-five deaths                     0.996629 -0.110777
# Polio                                -0.170689  0.214076
# Total expenditure                    -0.126564  0.294898
# Diphtheria                           -0.175156  0.215242
# HIV/AIDS                              0.025231 -0.048650
# GDP                                  -0.107109  0.318591
# Population                            0.548522 -0.030765
# thin1-19                              0.465590 -0.416946
# thin5-9                               0.471228 -0.405881
# Income composition of resources      -0.143663  0.416099
# Schooling                            -0.191757  0.497546
#
#                                  percentage expenditure  Hepatitis B  \
# Year                                           0.031400     0.089398
# Life expectancy                                0.381791     0.203771
# Adult Mortality                               -0.242814    -0.138591
# infant deaths                                 -0.085612    -0.178783
# Alcohol                                        0.339634     0.075447
# percentage expenditure                         1.000000     0.011679
# Hepatitis B                                    0.011679     1.000000
# Measles                                       -0.056596    -0.090317
# BMI                                            0.228537     0.134929
# under-five deaths                             -0.087852    -0.184413
# Polio                                          0.147259     0.408519
# Total expenditure                              0.173414     0.050084
# Diphtheria                                     0.143570     0.499958
# HIV/AIDS                                      -0.097857    -0.102405
# GDP                                            0.888140     0.062318
# Population                                    -0.024648    -0.109811
# thin1-19                                      -0.251190    -0.105144
# thin5-9                                       -0.252725    -0.108334
# Income composition of resources                0.380374     0.150992
# Schooling                                      0.388105     0.171755
#
#                                  Measles       BMI   under-five deaths   \
# Year                            -0.082493  0.108327           -0.042937
# Life expectancy                 -0.157574  0.559255           -0.222503
# Adult Mortality                  0.031174 -0.381449            0.094135
# infant deaths                    0.501128 -0.227220            0.996629
# Alcohol                         -0.051055  0.318070           -0.110777
# percentage expenditure          -0.056596  0.228537           -0.087852
# Hepatitis B                     -0.090317  0.134929           -0.184413
# Measles                          1.000000 -0.175925            0.507809
# BMI                             -0.175925  1.000000           -0.237586
# under-five deaths                0.507809 -0.237586            1.000000
# Polio                           -0.136166  0.282499           -0.188720
# Total expenditure               -0.104569  0.231814           -0.128269
# Diphtheria                      -0.141861  0.281059           -0.195651
# HIV/AIDS                         0.030899 -0.243548            0.038062
# GDP                             -0.068060  0.276645           -0.110640
# Population                       0.236250 -0.063238            0.535864
# thin1-19                         0.224742 -0.532025            0.467626
# thin5-9                          0.221007 -0.538911            0.472099
# Income composition of resources -0.115764  0.479837           -0.161533
# Schooling                       -0.122609  0.508105           -0.207111
#
#                                     Polio  Total expenditure  Diphtheria   \
# Year                             0.094158           0.081860     0.133853
# Life expectancy                  0.464531           0.207981     0.475418
# Adult Mortality                 -0.274218          -0.110875    -0.273014
# infant deaths                   -0.170689          -0.126564    -0.175156
# Alcohol                          0.214076           0.294898     0.215242
# percentage expenditure           0.147259           0.173414     0.143570
# Hepatitis B                      0.408519           0.050084     0.499958
# Measles                         -0.136166          -0.104569    -0.141861
# BMI                              0.282499           0.231814     0.281059
# under-five deaths               -0.188720          -0.128269    -0.195651
# Polio                            1.000000           0.130308     0.673553
# Total expenditure                0.130308           1.000000     0.145597
# Diphtheria                       0.673553           0.145597     1.000000
# HIV/AIDS                        -0.159560          -0.001383    -0.164787
# GDP                              0.194065           0.121467     0.182795
# Population                      -0.034886          -0.066698    -0.025458
# thin1-19                        -0.220213          -0.268724    -0.227820
# thin5-9                         -0.220976          -0.275240    -0.221105
# Income composition of resources  0.364983           0.149095     0.371729
# Schooling                        0.400978           0.218310     0.389944
#
#                                  HIV/AIDS       GDP  Population  thin1-19  \
# Year                            -0.139741  0.093351    0.014951 -0.047592
# Life expectancy                 -0.556457  0.430493   -0.019638 -0.472162
# Adult Mortality                  0.523727 -0.277053   -0.012501  0.299863
# infant deaths                    0.025231 -0.107109    0.548522  0.465590
# Alcohol                         -0.048650  0.318591   -0.030765 -0.416946
# percentage expenditure          -0.097857  0.888140   -0.024648 -0.251190
# Hepatitis B                     -0.102405  0.062318   -0.109811 -0.105144
# Measles                          0.030899 -0.068060    0.236250  0.224742
# BMI                             -0.243548  0.276645   -0.063238 -0.532025
# under-five deaths                0.038062 -0.110640    0.535864  0.467626
# Polio                           -0.159560  0.194065   -0.034886 -0.220213
# Total expenditure               -0.001383  0.121467   -0.066698 -0.268724
# Diphtheria                      -0.164787  0.182795   -0.025458 -0.227820
# HIV/AIDS                         1.000000 -0.134514   -0.027318  0.203922
# GDP                             -0.134514  1.000000   -0.025612 -0.267745
# Population                      -0.027318 -0.025612    1.000000  0.236117
# thin1-19                         0.203922 -0.267745    0.236117  1.000000
# thin5-9                          0.207140 -0.272400    0.233941  0.939102
# Income composition of resources -0.247454  0.440317   -0.007951 -0.406662
# Schooling                       -0.218620  0.429489   -0.029465 -0.446140
#
#                                   thin5-9  Income composition of resources  \
# Year                            -0.050627                         0.236333
# Life expectancy                 -0.466629                         0.692483
# Adult Mortality                  0.305366                        -0.440062
# infant deaths                    0.471228                        -0.143663
# Alcohol                         -0.405881                         0.416099
# percentage expenditure          -0.252725                         0.380374
# Hepatitis B                     -0.108334                         0.150992
# Measles                          0.221007                        -0.115764
# BMI                             -0.538911                         0.479837
# under-five deaths                0.472099                        -0.161533
# Polio                           -0.220976                         0.364983
# Total expenditure               -0.275240                         0.149095
# Diphtheria                      -0.221105                         0.371729
# HIV/AIDS                         0.207140                        -0.247454
# GDP                             -0.272400                         0.440317
# Population                       0.233941                        -0.007951
# thin1-19                         0.939102                        -0.406662
# thin5-9                          1.000000                        -0.395779
# Income composition of resources -0.395779                         1.000000
# Schooling                       -0.435777                         0.796207
#
#                                  Schooling
# Year                              0.203471
# Life expectancy                   0.715066
# Adult Mortality                  -0.435108
# infant deaths                    -0.191757
# Alcohol                           0.497546
# percentage expenditure            0.388105
# Hepatitis B                       0.171755
# Measles                          -0.122609
# BMI                               0.508105
# under-five deaths                -0.207111
# Polio                             0.400978
# Total expenditure                 0.218310
# Diphtheria                        0.389944
# HIV/AIDS                         -0.218620
# GDP                               0.429489
# Population                       -0.029465
# thin1-19                         -0.446140
# thin5-9                          -0.435777
# Income composition of resources   0.796207
# Schooling                         1.000000

# %%
sns.heatmap(corr_data)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x=df['Schooling'],y=df['Alcohol'])
# Out:
# <AxesSubplot:xlabel='Schooling', ylabel='Alcohol'>
